# %% [markdown]
# # Abanca

# %% [markdown]
# # ordem

# %% [markdown]
# ## 1.1

# %%
import pandas as pd 
import numpy as np 
import pdfplumber
from preprocessing import Ordem

# %%
abanca1_file = pdfplumber.open('abanca1.pdf')
abanca1_page5 = abanca1_file.pages[4]
pages = abanca1_file.pages
table = pages[4].extract_table(table_settings= {"vertical_strategy": "lines", "keep_blank_chars": False,"text_tolerance": 1})

# %%
pd.DataFrame(pages[4].extract_tables(table_settings= {}))
# Out:
#                                                   0   \
# 0  [None, None, , Comissões, None, None, None, No...
#
#                                                   1   \
# 0  [None, None, , Euros (Mín/Máx), , , Valor anua...
#
#                                                   2   \
# 0  [, Produtos: Fora de comercialização: Conta D....
#
#                                                   3   \
# 0  [None, Kids; Conta Global, None, None, None, N...
#
#                                                   4   \
# 0  [None, Em comercialização: Conta Base; Conta P...
#
#                                                   5   \
# 0  [None, Bancários, Conta Moeda Estrangeira e Co...
#
#                                                   6   \
# 0  [None, As comissões abaixo indicadas ocorrem n...
#
#                                                   7   \
# 0  [None, nos casos em que expressamente se exclu...
#
#                                                   8   \
# ...

# %%
df = pd.DataFrame(table)
# df=df.drop(columns= [4,5,14])
df = df.drop([0,1,2,3,4,5,6,7])
def new_df(x):
    return x.replace(np.nan, '*')
df= df.apply(new_df, axis = 1)
df = df.set_index(keys= 0)
df
# Out:
#                                                    1   \
# 0
# 1.  Emissão de extrato \n1.1  Mensal (enviado a...  *
# 2.   Fotocópias de segundas vias de talões de d...  *
# 3.   Manutenção de conta \n3.1 Conta D.O. Parti...  *
# 4.   Levantamento de numerário  \n 4.1 Ao balcã...  *
# 5.   Adesão ao serviço de banca à distância         *
# 6.  Depósito de moedas metálicas (igual ou supe...  *
# 7.  Alteração de titulares                          *
# 8.  Comissão por descoberto bancário                *
#
#                                                                                                    2   \
# 0
# 1.  Emissão de extrato \n1.1  Mensal (enviado a...                   Isento \n2,00 por extrato \n7,50
# 2.   Fotocópias de segundas vias de talões de d...                                 5,00 por documento
# 3.   Manutenção de conta \n3.1 Conta D.O. Parti...  15,00 Trimestral \n10,00 Trimestral \nIsento \...
# ...

# %%
for tab in table[0]:
    for element in tab
# Out:
# [[None,
#   None,
#   '',
#   'Comissões',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   'Acresce',
#   '',
#   '',
#   'Outras',
#   ''],
#  [None,
#   None,
#   '',
#   'Euros (Mín/Máx)',
#   '',
#   '',
#   'Valor anual',
#   None,
#   '',
#   None,
#   'Imposto',
#   None,
#   None,
#   'condições',
#   None],
#  ['',
#   'Produtos: Fora de comercialização: Conta D.O. Particulares; Conta Ordenado; Conta Standard; Conta Future; Conta',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   ''],
#  [None,
#   'Kids; Conta Global',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   'Em comercialização: Conta Base; Conta Private; Conta Value; Conta Smart; Conta Futuro; Conta Serviços Mínimos',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
# ...

# %%
im = pages[4].to_image(resolution=150)
im.draw_rects(pages[4].extract_words())

# %%
df.iloc[10]
# Out:
# 0     3.   Manutenção de conta \n3.1 Conta D.O. Part...
# 1                                                     *
# 2     15,00 Trimestral \n10,00 Trimestral \nIsento \...
# 3                                                     *
# 4                                                     *
# 5                                                     *
# 6                                                     *
# 7     60,00 \n40,00 \nn/a \nn/a \nn/a \nn/a \nn/a \n...
# 8                                                     *
# 9                                               IS – 4%
# 10                                                    *
# 11                                                    *
# 12
# 13                                                    *
# 14                                                    *
# Name: 10, dtype: object

# %%
# ctt = Ordem('ctt.pdf').get_df(4)

# %%
from tabula.io import read_pdf

# %%
df = read_pdf('abanca1.pdf',pages=5, multiple_tables=True)

# %%
print(df)
# Out:
#                                                    1   \
# 0
# 1.  Emissão de extrato \n1.1  Mensal (enviado a...  *
# 2.   Fotocópias de segundas vias de talões de d...  *
# 3.   Manutenção de conta \n3.1 Conta D.O. Parti...  *
# 4.   Levantamento de numerário  \n 4.1 Ao balcã...  *
# 5.   Adesão ao serviço de banca à distância         *
# 6.  Depósito de moedas metálicas (igual ou supe...  *
# 7.  Alteração de titulares                          *
# 8.  Comissão por descoberto bancário                *
#
#                                                                                                    2   \
# 0
# 1.  Emissão de extrato \n1.1  Mensal (enviado a...                   Isento \n2,00 por extrato \n7,50
# 2.   Fotocópias de segundas vias de talões de d...                                 5,00 por documento
# 3.   Manutenção de conta \n3.1 Conta D.O. Parti...  15,00 Trimestral \n10,00 Trimestral \nIsento \...
# ...

# %% [markdown]
# ## 17.1

# %%
abanca_excel=pd.read_excel('PWC.xlsx', sheet_name=2, nrows=30,usecols=[0,1,2,3] )

# %%
import tabula
df = tabula.read_pdf('abanca1.pdf', pages = 5)

# %%
import pdftables_api
  
# API KEY VERIFICATION
conversion = pdftables_api.Client('bpewr6iks9ep')
  
# PDf to Excel 
# (Hello.pdf, Hello)
conversion.xlsx("abanca1.pdf", "abanca.xlsx")

# %%
abanca_new =pd.read_excel('abanca.xlsx', sheet_name=4)
# Out:
# /Users/olgacravesana/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
abanca_new.set_index('Entrada em vigor: 20-Nov-2020')[8:]
# Out:
#                                                                                            Unnamed: 1  \
# Entrada em vigor: 20-Nov-2020
# 1.                                                  Emissão de extrato1.1 Mensal (enviado ao domic...
# 2.                                                  Fotocópias de segundas vias de talões de depósito
# 3.                                                                                Manutenção de conta
# NaN                                                              3.1 Conta D.O. Particulares (Nota 2)
# NaN                                                                          - Saldo médio até 1.000€
# NaN                                                               - Saldo médio entre 1.001€ e 2.500€
# NaN                                                                   - Saldo médio superior a 2.500€
# NaN                                                             3.2 Conta Ordenado (Nota 1 e Nota 16)
# ...
